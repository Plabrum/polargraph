# %%
from scipy import stats

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# %%
colors = [(e*0.6,0.2 + e*0.8,0) for e in np.linspace(0,1,100)]

# %%
# from https://stackoverflow.com/questions/25668828/how-to-create-colour-gradient-in-python

import math
from PIL import Image
im = Image.new('RGB', (604, 62))
ld = im.load()

def gaussian(x, a, b, c, d=0):
    return a * math.exp(-(x - b)**2 / (2 * c**2)) + d

for x in range(im.size[0]):
    r = int(gaussian(x, 158.8242, 201, 87.0739) + gaussian(x, 158.8242, 402, 87.0739))
    g = int(gaussian(x, 129.9851, 157.7571, 108.0298) + gaussian(x, 200.6831, 399.4535, 143.6828))
    b = int(gaussian(x, 231.3135, 206.4774, 201.5447) + gaussian(x, 17.1017, 395.8819, 39.3148))
    for y in range(im.size[1]):
        ld[x, y] = (r, g, b)

# %%
# Define the dimensions of the image
width, height = 512, 512

# Create an empty image canvas
spectrum_image = np.zeros((height, width, 3), dtype=np.uint8)

# Fill the image with the color spectrum
for x in range(width):
    r, g, b = [int(255 * c) for c in plt.cm.hsv(x / width)[:3]]
    spectrum_image[:, x, 0] = r
    spectrum_image[:, x, 1] = g
    spectrum_image[:, x, 2] = b

plt.imshow(spectrum_image)

# %%
 colors = {'r':[],'g':[],'b':[]}
 color_label_map = {'r':'red','g':'green','b':'blue'}
 for pos in range(257):
    r,g,b,a = plt.cm.hsv(pos)
    colors['r'].append(r)
    colors['g'].append(g)
    colors['b'].append(b)
    # colors['a'].append(a)

fig,ax = plt.subplots()
for c in colors.keys():

    ax.plot(colors[c], color=color_label_map[c], label=c)
fig.show()
# Out:
# /var/folders/8_/c1vkv8sd1r5f6dx71c15wjy40000gn/T/ipykernel_76599/1458469616.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def color_intensity(spectrum_position, intensity):

# %%
width, height = 200, 200
rgb_array = [[np.random.rand(3) for a in range(width)] for b in range(height)]
plt.imshow(rgb_array)

# %%
# from https://stackoverflow.com/questions/25668828/how-to-create-colour-gradient-in-python
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np

def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

c1='#1f77b4' #blue
c2='green' #green
n=500

fig, ax = plt.subplots(figsize=(8, 5))
for x in range(n+1):
    ax.axvline(x, color=colorFader(c1,c2,x/n), linewidth=4) 
plt.show()
