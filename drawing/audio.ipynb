# %%
from scipy.io import wavfile
samplerate, data = wavfile.read('sine_wave.wav')

# %%
data
# Out:
# array([   0, 3290, 6514, ...,  -30,   -7,    0], dtype=int16)

# %%
plt.figure(1)
plt.title("Signal Wave...")
plt.plot(data[:1000])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("sine_wave.wav", "r")

# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")


# If Stereo
if spf.getnchannels() == 2:
    print("Just mono files")
    sys.exit(0)

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/phil/repos/drawing/audio.ipynb Cell 3 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/phil/repos/drawing/audio.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> # Extract Raw Audio from Wav File
#      <a href='vscode-notebook-cell:/Users/phil/repos/drawing/audio.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> signal = spf.readframes(-1)
# ---> <a href='vscode-notebook-cell:/Users/phil/repos/drawing/audio.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> signal = np.fromstring(signal, "Int16")
#      <a href='vscode-notebook-cell:/Users/phil/repos/drawing/audio.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> # If Stereo
#      <a href='vscode-notebook-cell:/Users/phil/repos/drawing/audio.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> if spf.getnchannels() == 2:
#
# TypeError: data type 'Int16' not understood
